# %%
#1.  Use the inbuilt dataset 'titanic' as used . Plot a box plot for distribution of age with respect to each gender along with the information about whether they survived or not. (Column names: 'sex' and 'age')
#2.  Write observations on the inference from the above statistics.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-84f6do7n because the default path (/home/sauravmuke/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
df=pd.read_csv("Titanic-Dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
sns.boxplot(x=df['Sex'],y=df['Age']) #average age for male is between 20 to 40 and female is 18 to 38
# Out:
# <AxesSubplot: xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(x=df['Sex'],y=df['Age'],hue=df['Survived'])
# Out:
# <AxesSubplot: xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(x=df['Survived'],y=df['Age'])
# Out:
# <AxesSubplot: xlabel='Survived', ylabel='Age'>

# %%
sns.boxplot(x=df['Sex'],y=df['Survived'])
# Out:
# <AxesSubplot: xlabel='Sex', ylabel='Survived'>

# %%
sns.boxplot(x=df['Sex'],y=df['Fare'])
# Out:
# <AxesSubplot: xlabel='Sex', ylabel='Fare'>

# %%
sns.boxplot(x=df['Sex'],y=df['Pclass'])
# Out:
# <AxesSubplot: xlabel='Sex', ylabel='Pclass'>

# %%
sns.boxplot(x=df['Survived'],y=df['Fare'])
# Out:
# <AxesSubplot: xlabel='Survived', ylabel='Fare'>
